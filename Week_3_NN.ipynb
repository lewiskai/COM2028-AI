# %% [markdown]
# <a href="https://colab.research.google.com/github/lewiskai/COM2028-AI/blob/main/Week_3_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 3: Introduction to Artificial Neural Networks

# %%
# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# %% [markdown]
# ## Activation functions
# Activation functions are mathematical equations that determine the output of a neural network. The function is attached to each neuron in the network, and determines whether it should be activated (“fired”) or not, based on whether each neuron’s input is relevant for the model’s prediction. Activation functions also help normalize the output of each neuron.
#
# An additional aspect of activation functions is that they must be computationally efficient because they are calculated across thousands or even millions of neurons for each data sample. Modern neural networks use a technique called backpropagation to train the model, which places an increased computational strain on the activation function, and its derivative function.
#
# The popular activation functions and their derivatives are represented:

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def relu(z):
    return np.maximum(0, z)

def derivative(f, z, eps=0.000001):
    return (f(z + eps) - f(z - eps))/(2 * eps)

# %%
z = np.linspace(-5, 5, 200)

plt.figure(figsize=(11,4))

plt.subplot(121)
plt.plot(z, np.sign(z), "r-", linewidth=1, label="Step")
plt.plot(z, sigmoid(z), "g--", linewidth=2, label="Sigmoid")
plt.plot(z, np.tanh(z), "b-", linewidth=2, label="Tanh")
plt.plot(z, relu(z), "m-.", linewidth=2, label="ReLU")
plt.grid(True)
plt.legend(loc="center right", fontsize=14)
plt.title("Activation functions", fontsize=14)
plt.axis([-5, 5, -1.2, 1.2])

plt.subplot(122)
plt.plot(z, derivative(np.sign, z), "r-", linewidth=1, label="Step")
plt.plot(0, 0, "ro", markersize=5)
plt.plot(0, 0, "rx", markersize=10)
plt.plot(z, derivative(sigmoid, z), "g--", linewidth=2, label="Sigmoid")
plt.plot(z, derivative(np.tanh, z), "b-", linewidth=2, label="Tanh")
plt.plot(z, derivative(relu, z), "m-.", linewidth=2, label="ReLU")
plt.grid(True)
#plt.legend(loc="center right", fontsize=14)
plt.title("Derivatives", fontsize=14)
plt.axis([-5, 5, -0.2, 1.2])

plt.show()

# %% [markdown]
# ## NN for MNIST
#
# In this section we will build an MLP with TensorFlow, and we will implement Minibatch Gradient Descent to train it on the MNIST dataset. The first step is the construction phase, building the TensorFlow graph. The second step is the execution phase, where you actually run the graph to train the model.
#
# First we need to import the tensorflow library. Then we must specify the number of inputs and outputs, and set the number of hidden neurons in each layer:

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
x_train = x_train.reshape(-1, 28*28)
x_test = x_test.reshape(-1, 28*28)
y_train = y_train.astype(np.int32)
y_test = y_test.astype(np.int32)
x_valid, x_train = x_train[:5000], x_train[5000:]
y_valid, y_train = y_train[:5000], y_train[5000:]
print(x_train.shape)
# Out:
# (55000, 784)

# %% [markdown]
# # Building a model with Softmax
# Softmax extends this idea into a multi-class world. That is, Softmax assigns decimal probabilities to each class in a multi-class problem. Those decimal probabilities must add up to 1.0. This additional constraint helps training converge more quickly than it otherwise would.
#
# For example, returning to the image analysis we saw in Figure 1, Softmax might produce the following likelihoods of an image belonging to a particular class:
#
# ![softmax](https://raw.githubusercontent.com/hqsiswiliam/surrey_ai_lab_dataset/master/SoftmaxLayer.svg)
#
# - reference: [Multi-Class Neural Networks: Softmax](https://developers.google.com/machine-learning/crash-course/multi-class-neural-networks/softmax)

# %%
n_inputs = 28*28  # MNIST
n_hidden1 = 256
n_hidden2 = 128
n_outputs = 10

model = keras.Sequential(
    [
        keras.Input(shape=(28*28,)),
        layers.Dense(n_hidden1, name='hidden1', activation='relu'),
        layers.Dense(n_hidden2, name='hidden2', activation='relu'),
        layers.Dense(n_outputs, activation="softmax")
    ]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden1 (Dense)             (None, 256)               200960
#
#  hidden2 (Dense)             (None, 128)               32896
#
#  dense (Dense)               (None, 10)                1290
#
# =================================================================
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now that we have the neural network model ready to go, we need to define the cost function that we will use to train it. We will use cross entropy, cross entropy will penalize models that estimate a low probability for the target class.

# %%
crossentropy = keras.losses.CategoricalCrossentropy()

# %% [markdown]
# We have the neural network model, we have the cost function, and now we need to define a GradientDescentOptimizer that will tweak the model parameters to minimize the cost function.

# %%
learning_rate = 0.001
optimizer = keras.optimizers.SGD(learning_rate=learning_rate)
accuracy = keras.metrics.CategoricalAccuracy()

# %% [markdown]
# And now we can train the model:

# %%
model.compile(loss=crossentropy, optimizer=optimizer, metrics=[accuracy])
model.fit(x_train,y_train,batch_size=128,epochs=10,validation_data=(x_valid,y_valid), shuffle=True)
# Out:
# Epoch 1/10
# 430/430 [==============================] - 3s 5ms/step - loss: 2.2191 - categorical_accuracy: 0.2306 - val_loss: 2.0924 - val_categorical_accuracy: 0.3656
# Epoch 2/10
# 430/430 [==============================] - 2s 4ms/step - loss: 1.9651 - categorical_accuracy: 0.5016 - val_loss: 1.8254 - val_categorical_accuracy: 0.6002
# Epoch 3/10
# 430/430 [==============================] - 2s 4ms/step - loss: 1.6891 - categorical_accuracy: 0.6688 - val_loss: 1.5376 - val_categorical_accuracy: 0.7150
# Epoch 4/10
# 430/430 [==============================] - 2s 4ms/step - loss: 1.4122 - categorical_accuracy: 0.7469 - val_loss: 1.2734 - val_categorical_accuracy: 0.7658
# Epoch 5/10
# 430/430 [==============================] - 2s 4ms/step - loss: 1.1748 - categorical_accuracy: 0.7860 - val_loss: 1.0619 - val_categorical_accuracy: 0.7972
# Epoch 6/10
# 430/430 [==============================] - 2s 4ms/step - loss: 0.9916 - categorical_accuracy: 0.8108 - val_loss: 0.9037 - val_categorical_accuracy: 0.8170
# Epoch 7/10
# 430/430 [==============================] - 2s 4ms/step - loss: 0.8578 - categorical_accuracy: 0.8261 - val_loss: 0.7896 - val_categorical_accuracy: 0.8344
# Epoch 8/10
# 430/430 [==============================] - 2s 4ms/step - loss: 0.7614 - categorical_accuracy: 0.8370 - val_loss: 0.7066 - val_categorical_accuracy: 0.8458
# Epoch 9/10
# 430/430 [==============================] - 2s 4ms/step - loss: 0.6901 - categorical_accuracy: 0.8459 - val_loss: 0.6441 - val_categorical_accuracy: 0.8532
# Epoch 10/10
# 430/430 [==============================] - 2s 4ms/step - loss: 0.6359 - categorical_accuracy: 0.8519 - val_loss: 0.5958 - val_categorical_accuracy: 0.8588

# %% [markdown]
# Now that the neural network is trained, you can use it to make predictions. To do that, you can reuse the same construction phase, but change the execution phase like this:

# %%
y_pred = model.predict(x_test)
# Since y_pred only output probabilities over classes, we retrieve the one with max probability
y_pred = np.argmax(y_pred, axis=1)
y_test_argmax = np.argmax(y_test, axis=1)
print("Predicted classes:", y_pred)
print("Actual classes:   ", y_test_argmax)
# Out:
# Predicted classes: [7 2 1 ... 4 8 6]
# Actual classes:    [7 2 1 ... 4 5 6]

# %% [markdown]
# ## <font color='red'> Task1</font>
#
# **Task 1:** Train your own MLP on the MNIST dataset and see if you can get over 95% precision.

# %% [markdown]
# **This can be achieved by many ways, here we just replace SGD optmiser by Adam optimiser.**

# %%
n_inputs = 28*28  # MNIST
n_hidden1 = 256
n_hidden2 = 128
n_outputs = 10

model = keras.Sequential(
    [
        keras.Input(shape=(28*28,)),
        layers.Dense(n_hidden1, name='hidden1', activation='relu'),
        layers.Dense(n_hidden2, name='hidden2', activation='relu'),
        layers.Dense(n_outputs, activation="softmax")
    ]
)

model.summary()
crossentropy = keras.losses.CategoricalCrossentropy()
learning_rate = 0.001
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
accuracy = keras.metrics.CategoricalAccuracy()
model.compile(loss=crossentropy, optimizer=optimizer, metrics=[accuracy])
model.fit(x_train,y_train,batch_size=128,epochs=10,validation_data=(x_valid,y_valid), shuffle=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden1 (Dense)             (None, 256)               200960
#
#  hidden2 (Dense)             (None, 128)               32896
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 430/430 [==============================] - 3s 5ms/step - loss: 0.2828 - categorical_accuracy: 0.9187 - val_loss: 0.1230 - val_categorical_accuracy: 0.9632
# Epoch 2/10
# 430/430 [==============================] - 2s 5ms/step - loss: 0.1095 - categorical_accuracy: 0.9671 - val_loss: 0.1078 - val_categorical_accuracy: 0.9656
# Epoch 3/10
# 430/430 [==============================] - 2s 5ms/step - loss: 0.0707 - categorical_accuracy: 0.9782 - val_loss: 0.0777 - val_categorical_accuracy: 0.9770
# Epoch 4/10
# 430/430 [==============================] - 2s 5ms/step - loss: 0.0496 - categorical_accuracy: 0.9844 - val_loss: 0.0713 - val_categorical_accuracy: 0.9762
# Epoch 5/10
# 430/430 [==============================] - 2s 5ms/step - loss: 0.0367 - categorical_accuracy: 0.9887 - val_loss: 0.0681 - val_categorical_accuracy: 0.9808
# Epoch 6/10
# 430/430 [==============================] - 2s 4ms/step - loss: 0.0267 - categorical_accuracy: 0.9918 - val_loss: 0.0742 - val_categorical_accuracy: 0.9786
# Epoch 7/10
# 430/430 [==============================] - 2s 4ms/step - loss: 0.0209 - categorical_accuracy: 0.9933 - val_loss: 0.0775 - val_categorical_accuracy: 0.9776
# Epoch 8/10
# 430/430 [==============================] - 2s 4ms/step - loss: 0.0165 - categorical_accuracy: 0.9949 - val_loss: 0.0725 - val_categorical_accuracy: 0.9794
# Epoch 9/10
# 430/430 [==============================] - 2s 4ms/step - loss: 0.0167 - categorical_accuracy: 0.9946 - val_loss: 0.0710 - val_categorical_accuracy: 0.9822
# Epoch 10/10
# 430/430 [==============================] - 2s 4ms/step - loss: 0.0116 - categorical_accuracy: 0.9962 - val_loss: 0.0698 - val_categorical_accuracy: 0.9816

# %%
learning_rate = 0.001
optimizer = keras.optimizers.SGD(learning_rate=learning_rate)
accuracy = keras.metrics.CategoricalAccuracy()

# %% [markdown]
# # Challenge Part: Tumour classification
# We have a dataset containing measurements of breast tumours. This is a classification task, unlike last week's which was regression.
#
# - Labels:
#   - 'B' for benign (noncancerous)
#   - 'M' for malignant (cancerous)
# - Notes:
#   - You can use loss related to binary
#   - Different activation functions might impact your model
#   - You could look at feature-wise normalisation, which may help your model's performance, [using utility functions from scikit-learn](https://scikit-learn.org/stable/modules/preprocessing.html)
#   - The Kaggle link is: https://www.kaggle.com/t/3cd15e8c85774fd88ae312a9783db8f1
#   - **Please also set your team name to your URN on Kaggle. You may need to return to lab 2's competition page and do this too.**

# %% [markdown]
# Set up environment variables for Kaggle (same as in last lab):

# %%
import os
os.environ['KAGGLE_USERNAME'] = 'jimcai27'  # Your Kaggle username
os.environ['KAGGLE_KEY'] = '9090ff37359010440cbc99c60aba700d'  # Your Kaggle API key
os.environ['URN'] = '6623075'  # Your URN: submissions without a URN will not count

# %% [markdown]
# Download the dataset.
#
# Note we invoke Kaggle using `!python`, this means it uses Python 3 and Kaggle 1.5.12. Calling `!kaggle` uses Python 2 and Kaggle 1.5.4. The `kaggle` script defaults to Python 2, hence this difference.

# %%
# !kaggle -v
# !python3 -m pip show kaggle
# Out:
# Kaggle API 1.5.12
# Name: kaggle
# Version: 1.5.12
# Summary: Kaggle API
# Home-page: https://github.com/Kaggle/kaggle-api
# Author: Kaggle
# Author-email: support@kaggle.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: requests, six, urllib3, python-dateutil, tqdm, certifi, python-slugify
# Required-by:

# %%
# !python3 /usr/local/bin/kaggle -v
# !python3 -m pip show kaggle
# Out:
# Kaggle API 1.5.12
# Name: kaggle
# Version: 1.5.12
# Summary: Kaggle API
# Home-page: https://github.com/Kaggle/kaggle-api
# Author: Kaggle
# Author-email: support@kaggle.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: certifi, python-slugify, requests, six, tqdm, python-dateutil, urllib3
# Required-by:

# %%
# !python3 /usr/local/bin/kaggle competitions download -c uos-com2028-21-22-lab3 --force
# !unzip uos-com2028-21-22-lab3.zip
# Out:
# Downloading uos-com2028-21-22-lab3.zip to /content
#   0% 0.00/46.9k [00:00<?, ?B/s]
# 100% 46.9k/46.9k [00:00<00:00, 35.2MB/s]
# Archive:  uos-com2028-21-22-lab3.zip
# replace BreastCancerTest.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# Now to load the dataset:

# %%
import pandas as pd
from tensorflow.keras.utils import to_categorical

train_bc = pd.read_csv('BreastCancerTrain.csv')
test_bc = pd.read_csv('BreastCancerTest.csv')

print(f'Training set sample (target=weight): \n{train_bc[:10]}\n\n')
print(f'Testing set sample (target=weight): \n{test_bc[:3]}\n\n')

# Return all columns that are not the target, 'diagnosis', as a numpy array
X_train_bc = train_bc.loc[:, train_bc.columns != 'diagnosis'].values
X_test_bc = test_bc.loc[:, test_bc.columns != 'id'].values

# Return only the 'diagnosis' column as a numpy array
y_train_bc = train_bc.loc[:, 'diagnosis'].values

# We need to convert the dataset target classes from strings 'M' and 'B' to a 
# boolean indicating 'Is Malignant?'
y_train_bc_bool = y_train_bc == 'M'

# If you want to use one-hot encoding:
y_train_bc_onehot = to_categorical(y_train_bc_bool, 2)

print('Training sample shape', X_train_bc.shape, 'example:', X_train_bc[0])
print('Training target shape one-hot', y_train_bc_onehot.shape, 'example:', y_train_bc_onehot[0])
print('Training target shape bool', y_train_bc_bool.shape, 'example:', y_train_bc_bool[0])
print('Testing sample shape', X_test_bc.shape, 'example:', X_test_bc[0])
# Out:
# Training set sample (target=weight):
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         B       13.270         14.76           84.74      551.7
# 1         B       14.060         17.18           89.75      609.1
# 2         B       10.290         27.61           65.67      321.4
# 3         B        9.738         11.97           61.24      288.5
# 4         B       15.710         13.93          102.00      761.7
# 5         B       11.370         18.89           72.17      396.0
# 6         B       12.560         19.07           81.92      485.8
# 7         B        8.878         15.49           56.74      241.0
# 8         B       14.690         13.98           98.22      656.1
# 9         M       18.220         18.87          118.70     1027.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.07355           0.05055         0.03261              0.02648
# 1          0.08045           0.05361         0.02681              0.03251
# 2          0.09030           0.07658         0.05999              0.02738
# 3          0.09250           0.04102         0.00000              0.00000
# 4          0.09462           0.09462         0.07135              0.05933
# 5          0.08713           0.05008         0.02399              0.02173
# 6          0.08760           0.10380         0.10300              0.04391
# 7          0.08293           0.07698         0.04721              0.02381
# 8          0.10310           0.18360         0.14500              0.06300
# 9          0.09746           0.11170         0.11300              0.07950
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.1386  ...        16.360          22.35           104.50
# 1         0.1641  ...        14.920          25.34            96.42
# 2         0.1593  ...        10.840          34.91            69.57
# 3         0.1903  ...        10.620          14.10            66.53
# 4         0.1816  ...        17.500          19.25           114.30
# 5         0.2013  ...        12.360          26.14            79.29
# 6         0.1533  ...        13.370          22.43            89.02
# 7         0.1930  ...         9.981          17.70            65.27
# 8         0.2086  ...        16.460          18.34           114.10
# 9         0.1807  ...        21.840          25.00           140.90
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0       830.6            0.1006            0.12380          0.13500
# 1       684.5            0.1066            0.12310          0.08460
# 2       357.6            0.1384            0.17100          0.20000
# 3       342.9            0.1234            0.07204          0.00000
# 4       922.8            0.1223            0.19490          0.17090
# 5       459.3            0.1118            0.09708          0.07529
# 6       547.4            0.1096            0.20020          0.23880
# 7       302.0            0.1015            0.12480          0.09441
# 8       809.2            0.1312            0.36350          0.32190
# 9      1485.0            0.1434            0.27630          0.38530
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0               0.10010          0.2027                  0.06206
# 1               0.07911          0.2523                  0.06609
# 2               0.09127          0.2226                  0.08283
# 3               0.00000          0.3105                  0.08151
# 4               0.13740          0.2723                  0.07071
# 5               0.06203          0.3267                  0.06994
# 6               0.09265          0.2121                  0.07188
# 7               0.04762          0.2434                  0.07431
# 8               0.11080          0.2827                  0.09208
# 9               0.17760          0.2812                  0.08198
#
# [10 rows x 31 columns]
#
#
# Testing set sample (target=weight):
#    id  radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0   0       15.730         11.28          102.80      747.2           0.1043
# 1   1        8.734         16.84           55.27      234.3           0.1039
# 2   2       15.320         17.27          103.20      713.3           0.1335
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  ...  \
# 0           0.12990          0.1191              0.06211         0.1784  ...
# 1           0.07428          0.0000              0.00000         0.1985  ...
# 2           0.22840          0.2448              0.12420         0.2398  ...
#
#    radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0         17.01          14.20           112.50       854.3            0.1541
# 1         10.17          22.80            64.01       317.0            0.1460
# 2         17.73          22.66           119.80       928.8            0.1765
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.2979           0.4004                0.1452          0.2557
# 1             0.1310           0.0000                0.0000          0.2445
# 2             0.4503           0.4429                0.2229          0.3258
#
#    fractal_dimension_worst
# 0                  0.08181
# 1                  0.08865
# 2                  0.11910
#
# [3 rows x 31 columns]
#
#
# Training sample shape (447, 30) example: [1.327e+01 1.476e+01 8.474e+01 5.517e+02 7.355e-02 5.055e-02 3.261e-02
#  2.648e-02 1.386e-01 5.318e-02 4.057e-01 1.153e+00 2.701e+00 3.635e+01
#  4.481e-03 1.038e-02 1.358e-02 1.082e-02 1.069e-02 1.435e-03 1.636e+01
#  2.235e+01 1.045e+02 8.306e+02 1.006e-01 1.238e-01 1.350e-01 1.001e-01
#  2.027e-01 6.206e-02]
# Training target shape one-hot (447, 2) example: [1. 0.]
# Training target shape bool (447,) example: False
# Testing sample shape (113, 30) example: [1.573e+01 1.128e+01 1.028e+02 7.472e+02 1.043e-01 1.299e-01 1.191e-01
#  6.211e-02 1.784e-01 6.259e-02 1.630e-01 3.871e-01 1.143e+00 1.387e+01
#  6.034e-03 1.820e-02 3.336e-02 1.067e-02 1.175e-02 2.256e-03 1.701e+01
#  1.420e+01 1.125e+02 8.543e+02 1.541e-01 2.979e-01 4.004e-01 1.452e-01
#  2.557e-01 8.181e-02]

# %% [markdown]
# Now build your classifier!

# %%
# Your code here: build your NN classifier
n_inputs = 30
n_hidden1 = 300
n_hidden2 = 100
n_outputs = 2

model = keras.Sequential(
    [
        keras.Input(shape=(30,)),
        layers.Dense(n_hidden1, name='hidden1', activation='relu'),
        layers.Dense(n_hidden2, name='hidden2', activation='relu'),
        layers.Dense(n_outputs, activation="softmax")
    ]
)

model.summary()
crossentropy = keras.losses.CategoricalCrossentropy()
learning_rate = 0.00075
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
accuracy = keras.metrics.CategoricalAccuracy()
model.compile(loss=crossentropy, optimizer=optimizer, metrics=[accuracy])
model.fit(X_train_bc,y_train_bc_onehot,batch_size=128,epochs=1000,validation_split=(0.2), shuffle=True)
# Set predictions to the output of your model
predictions = model.predict(X_test_bc)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden1 (Dense)             (None, 300)               9300
#
#  hidden2 (Dense)             (None, 100)               30100
#
#  dense_5 (Dense)             (None, 2)                 202
#
# =================================================================
# Total params: 39,602
# Trainable params: 39,602
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 3/3 [==============================] - 1s 101ms/step - loss: 15.7672 - categorical_accuracy: 0.5266 - val_loss: 0.1793 - val_categorical_accuracy: 0.9222
# Epoch 2/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 10.3961 - categorical_accuracy: 0.7255 - val_loss: 0.7815 - val_categorical_accuracy: 0.8444
# Epoch 3/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 6.8909 - categorical_accuracy: 0.5182 - val_loss: 12.2722 - val_categorical_accuracy: 0.3556
# Epoch 4/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 5.4417 - categorical_accuracy: 0.5630 - val_loss: 3.7717 - val_categorical_accuracy: 0.7333
# Epoch 5/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 4.4700 - categorical_accuracy: 0.7535 - val_loss: 0.5759 - val_categorical_accuracy: 0.8778
# Epoch 6/1000
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3651 - categorical_accuracy: 0.7899 - val_loss: 3.1863 - val_categorical_accuracy: 0.6000
# Epoch 7/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 1.4721 - categorical_accuracy: 0.7927 - val_loss: 0.6688 - val_categorical_accuracy: 0.8889
# Epoch 8/1000
# 3/3 [==============================] - 0s 16ms/step - loss: 1.6759 - categorical_accuracy: 0.8655 - val_loss: 0.6916 - val_categorical_accuracy: 0.9000
# Epoch 9/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.7402 - categorical_accuracy: 0.9076 - val_loss: 1.6749 - val_categorical_accuracy: 0.8000
# Epoch 10/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 1.3014 - categorical_accuracy: 0.8039 - val_loss: 0.4851 - val_categorical_accuracy: 0.9222
# Epoch 11/1000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9932 - categorical_accuracy: 0.8964 - val_loss: 0.9640 - val_categorical_accuracy: 0.8889
# Epoch 12/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1144 - categorical_accuracy: 0.9048 - val_loss: 0.5754 - val_categorical_accuracy: 0.9111
# Epoch 13/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7020 - categorical_accuracy: 0.8824 - val_loss: 1.0011 - val_categorical_accuracy: 0.8444
# Epoch 14/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6180 - categorical_accuracy: 0.8852 - val_loss: 0.5384 - val_categorical_accuracy: 0.9333
# Epoch 15/1000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7432 - categorical_accuracy: 0.9076 - val_loss: 0.4656 - val_categorical_accuracy: 0.9222
# Epoch 16/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5987 - categorical_accuracy: 0.9132 - val_loss: 0.7480 - val_categorical_accuracy: 0.8778
# Epoch 17/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.5028 - categorical_accuracy: 0.9048 - val_loss: 0.4641 - val_categorical_accuracy: 0.9222
# Epoch 18/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.5523 - categorical_accuracy: 0.9244 - val_loss: 0.4664 - val_categorical_accuracy: 0.9222
# Epoch 19/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4119 - categorical_accuracy: 0.9244 - val_loss: 0.6249 - val_categorical_accuracy: 0.8556
# Epoch 20/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4340 - categorical_accuracy: 0.9188 - val_loss: 0.4585 - val_categorical_accuracy: 0.9222
# Epoch 21/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4260 - categorical_accuracy: 0.9160 - val_loss: 0.4632 - val_categorical_accuracy: 0.9111
# Epoch 22/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3863 - categorical_accuracy: 0.9188 - val_loss: 0.5140 - val_categorical_accuracy: 0.8778
# Epoch 23/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.4202 - categorical_accuracy: 0.9104 - val_loss: 0.4396 - val_categorical_accuracy: 0.9222
# Epoch 24/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4531 - categorical_accuracy: 0.9104 - val_loss: 0.4227 - val_categorical_accuracy: 0.9222
# Epoch 25/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4543 - categorical_accuracy: 0.9132 - val_loss: 0.5008 - val_categorical_accuracy: 0.8667
# Epoch 26/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4118 - categorical_accuracy: 0.9160 - val_loss: 0.4193 - val_categorical_accuracy: 0.9222
# Epoch 27/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3820 - categorical_accuracy: 0.9160 - val_loss: 0.5703 - val_categorical_accuracy: 0.8667
# Epoch 28/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3557 - categorical_accuracy: 0.9328 - val_loss: 0.4042 - val_categorical_accuracy: 0.9222
# Epoch 29/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.4013 - categorical_accuracy: 0.9216 - val_loss: 0.4196 - val_categorical_accuracy: 0.8889
# Epoch 30/1000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4031 - categorical_accuracy: 0.9076 - val_loss: 0.3622 - val_categorical_accuracy: 0.9333
# Epoch 31/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3995 - categorical_accuracy: 0.9188 - val_loss: 0.3561 - val_categorical_accuracy: 0.9222
# Epoch 32/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2968 - categorical_accuracy: 0.9216 - val_loss: 0.4150 - val_categorical_accuracy: 0.8667
# Epoch 33/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3073 - categorical_accuracy: 0.9272 - val_loss: 0.3373 - val_categorical_accuracy: 0.9333
# Epoch 34/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3063 - categorical_accuracy: 0.9272 - val_loss: 0.4217 - val_categorical_accuracy: 0.8556
# Epoch 35/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2935 - categorical_accuracy: 0.9244 - val_loss: 0.3167 - val_categorical_accuracy: 0.9333
# Epoch 36/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3286 - categorical_accuracy: 0.9244 - val_loss: 0.4059 - val_categorical_accuracy: 0.8556
# Epoch 37/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2988 - categorical_accuracy: 0.9188 - val_loss: 0.3137 - val_categorical_accuracy: 0.9222
# Epoch 38/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2772 - categorical_accuracy: 0.9272 - val_loss: 0.4097 - val_categorical_accuracy: 0.8556
# Epoch 39/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3168 - categorical_accuracy: 0.9160 - val_loss: 0.2893 - val_categorical_accuracy: 0.9333
# Epoch 40/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2840 - categorical_accuracy: 0.9160 - val_loss: 0.2824 - val_categorical_accuracy: 0.9333
# Epoch 41/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2452 - categorical_accuracy: 0.9244 - val_loss: 0.3331 - val_categorical_accuracy: 0.8667
# Epoch 42/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.3085 - categorical_accuracy: 0.9132 - val_loss: 0.3254 - val_categorical_accuracy: 0.8667
# Epoch 43/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2561 - categorical_accuracy: 0.9132 - val_loss: 0.2649 - val_categorical_accuracy: 0.9333
# Epoch 44/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2367 - categorical_accuracy: 0.9272 - val_loss: 0.2598 - val_categorical_accuracy: 0.9333
# Epoch 45/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2363 - categorical_accuracy: 0.9188 - val_loss: 0.2544 - val_categorical_accuracy: 0.9333
# Epoch 46/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2258 - categorical_accuracy: 0.9300 - val_loss: 0.2664 - val_categorical_accuracy: 0.9000
# Epoch 47/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2358 - categorical_accuracy: 0.9356 - val_loss: 0.2426 - val_categorical_accuracy: 0.9333
# Epoch 48/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2136 - categorical_accuracy: 0.9216 - val_loss: 0.2471 - val_categorical_accuracy: 0.9222
# Epoch 49/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2036 - categorical_accuracy: 0.9300 - val_loss: 0.2506 - val_categorical_accuracy: 0.9333
# Epoch 50/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2538 - categorical_accuracy: 0.9160 - val_loss: 0.2404 - val_categorical_accuracy: 0.9111
# Epoch 51/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3154 - categorical_accuracy: 0.9048 - val_loss: 0.5235 - val_categorical_accuracy: 0.8111
# Epoch 52/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3575 - categorical_accuracy: 0.8992 - val_loss: 0.2933 - val_categorical_accuracy: 0.9222
# Epoch 53/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2843 - categorical_accuracy: 0.9020 - val_loss: 0.2126 - val_categorical_accuracy: 0.9333
# Epoch 54/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2222 - categorical_accuracy: 0.9244 - val_loss: 0.2177 - val_categorical_accuracy: 0.9333
# Epoch 55/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2243 - categorical_accuracy: 0.9160 - val_loss: 0.2330 - val_categorical_accuracy: 0.9333
# Epoch 56/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2511 - categorical_accuracy: 0.9160 - val_loss: 0.2129 - val_categorical_accuracy: 0.9333
# Epoch 57/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2400 - categorical_accuracy: 0.9160 - val_loss: 0.2478 - val_categorical_accuracy: 0.8889
# Epoch 58/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2201 - categorical_accuracy: 0.9216 - val_loss: 0.2531 - val_categorical_accuracy: 0.8889
# Epoch 59/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2092 - categorical_accuracy: 0.9160 - val_loss: 0.2856 - val_categorical_accuracy: 0.9222
# Epoch 60/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3868 - categorical_accuracy: 0.8908 - val_loss: 0.2076 - val_categorical_accuracy: 0.9444
# Epoch 61/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3489 - categorical_accuracy: 0.9104 - val_loss: 0.4201 - val_categorical_accuracy: 0.8333
# Epoch 62/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2308 - categorical_accuracy: 0.9244 - val_loss: 0.2921 - val_categorical_accuracy: 0.9222
# Epoch 63/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2034 - categorical_accuracy: 0.9272 - val_loss: 0.5424 - val_categorical_accuracy: 0.8111
# Epoch 64/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4002 - categorical_accuracy: 0.8824 - val_loss: 0.1886 - val_categorical_accuracy: 0.9333
# Epoch 65/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.4860 - categorical_accuracy: 0.8515 - val_loss: 0.5870 - val_categorical_accuracy: 0.8667
# Epoch 66/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4336 - categorical_accuracy: 0.8992 - val_loss: 0.6849 - val_categorical_accuracy: 0.7444
# Epoch 67/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4975 - categorical_accuracy: 0.8599 - val_loss: 0.2848 - val_categorical_accuracy: 0.9000
# Epoch 68/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3725 - categorical_accuracy: 0.8852 - val_loss: 0.3623 - val_categorical_accuracy: 0.9111
# Epoch 69/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3323 - categorical_accuracy: 0.9132 - val_loss: 1.0649 - val_categorical_accuracy: 0.7111
# Epoch 70/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4384 - categorical_accuracy: 0.8571 - val_loss: 0.3773 - val_categorical_accuracy: 0.9111
# Epoch 71/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4287 - categorical_accuracy: 0.8739 - val_loss: 0.2122 - val_categorical_accuracy: 0.9333
# Epoch 72/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3481 - categorical_accuracy: 0.9188 - val_loss: 0.3741 - val_categorical_accuracy: 0.8667
# Epoch 73/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3194 - categorical_accuracy: 0.8936 - val_loss: 0.3186 - val_categorical_accuracy: 0.9222
# Epoch 74/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2628 - categorical_accuracy: 0.9244 - val_loss: 0.5631 - val_categorical_accuracy: 0.8222
# Epoch 75/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5453 - categorical_accuracy: 0.8683 - val_loss: 0.2393 - val_categorical_accuracy: 0.9444
# Epoch 76/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4027 - categorical_accuracy: 0.8880 - val_loss: 0.2578 - val_categorical_accuracy: 0.9333
# Epoch 77/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3902 - categorical_accuracy: 0.9020 - val_loss: 0.6175 - val_categorical_accuracy: 0.8111
# Epoch 78/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3699 - categorical_accuracy: 0.9048 - val_loss: 0.2611 - val_categorical_accuracy: 0.9333
# Epoch 79/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2265 - categorical_accuracy: 0.9384 - val_loss: 0.6628 - val_categorical_accuracy: 0.7889
# Epoch 80/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4306 - categorical_accuracy: 0.8852 - val_loss: 0.2465 - val_categorical_accuracy: 0.9444
# Epoch 81/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2042 - categorical_accuracy: 0.9300 - val_loss: 0.3348 - val_categorical_accuracy: 0.8778
# Epoch 82/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3353 - categorical_accuracy: 0.9132 - val_loss: 0.2133 - val_categorical_accuracy: 0.9111
# Epoch 83/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2535 - categorical_accuracy: 0.9244 - val_loss: 0.2601 - val_categorical_accuracy: 0.9333
# Epoch 84/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3049 - categorical_accuracy: 0.9160 - val_loss: 0.1940 - val_categorical_accuracy: 0.9333
# Epoch 85/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1908 - categorical_accuracy: 0.9300 - val_loss: 0.2331 - val_categorical_accuracy: 0.9000
# Epoch 86/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2504 - categorical_accuracy: 0.9020 - val_loss: 0.2248 - val_categorical_accuracy: 0.9444
# Epoch 87/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2044 - categorical_accuracy: 0.9272 - val_loss: 0.2666 - val_categorical_accuracy: 0.9000
# Epoch 88/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1896 - categorical_accuracy: 0.9272 - val_loss: 0.1882 - val_categorical_accuracy: 0.9444
# Epoch 89/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2595 - categorical_accuracy: 0.9104 - val_loss: 0.2556 - val_categorical_accuracy: 0.9333
# Epoch 90/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2231 - categorical_accuracy: 0.9300 - val_loss: 0.2278 - val_categorical_accuracy: 0.9111
# Epoch 91/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2707 - categorical_accuracy: 0.9216 - val_loss: 0.2936 - val_categorical_accuracy: 0.8778
# Epoch 92/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1916 - categorical_accuracy: 0.9188 - val_loss: 0.1990 - val_categorical_accuracy: 0.9444
# Epoch 93/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2335 - categorical_accuracy: 0.9104 - val_loss: 0.2947 - val_categorical_accuracy: 0.9222
# Epoch 94/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3920 - categorical_accuracy: 0.8852 - val_loss: 0.2569 - val_categorical_accuracy: 0.9222
# Epoch 95/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4316 - categorical_accuracy: 0.8739 - val_loss: 0.2534 - val_categorical_accuracy: 0.8889
# Epoch 96/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.2332 - categorical_accuracy: 0.9188 - val_loss: 0.2062 - val_categorical_accuracy: 0.9111
# Epoch 97/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2097 - categorical_accuracy: 0.9244 - val_loss: 0.2086 - val_categorical_accuracy: 0.9333
# Epoch 98/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2292 - categorical_accuracy: 0.9328 - val_loss: 0.1698 - val_categorical_accuracy: 0.9444
# Epoch 99/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2429 - categorical_accuracy: 0.9244 - val_loss: 0.4081 - val_categorical_accuracy: 0.8333
# Epoch 100/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.2820 - categorical_accuracy: 0.8992 - val_loss: 0.2215 - val_categorical_accuracy: 0.9000
# Epoch 101/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3470 - categorical_accuracy: 0.8824 - val_loss: 0.6041 - val_categorical_accuracy: 0.8667
# Epoch 102/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5175 - categorical_accuracy: 0.8515 - val_loss: 0.1875 - val_categorical_accuracy: 0.9444
# Epoch 103/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.4348 - categorical_accuracy: 0.8908 - val_loss: 1.0371 - val_categorical_accuracy: 0.7111
# Epoch 104/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7334 - categorical_accuracy: 0.8235 - val_loss: 0.1812 - val_categorical_accuracy: 0.9333
# Epoch 105/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.4651 - categorical_accuracy: 0.8683 - val_loss: 0.4433 - val_categorical_accuracy: 0.9111
# Epoch 106/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.5169 - categorical_accuracy: 0.8992 - val_loss: 0.7623 - val_categorical_accuracy: 0.8111
# Epoch 107/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4330 - categorical_accuracy: 0.9048 - val_loss: 0.5350 - val_categorical_accuracy: 0.8889
# Epoch 108/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4392 - categorical_accuracy: 0.8936 - val_loss: 1.2408 - val_categorical_accuracy: 0.7222
# Epoch 109/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6970 - categorical_accuracy: 0.8487 - val_loss: 0.4857 - val_categorical_accuracy: 0.9111
# Epoch 110/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5496 - categorical_accuracy: 0.8936 - val_loss: 0.3087 - val_categorical_accuracy: 0.9111
# Epoch 111/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2722 - categorical_accuracy: 0.9188 - val_loss: 0.3162 - val_categorical_accuracy: 0.9333
# Epoch 112/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2473 - categorical_accuracy: 0.9356 - val_loss: 0.4520 - val_categorical_accuracy: 0.8778
# Epoch 113/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3737 - categorical_accuracy: 0.9104 - val_loss: 0.4151 - val_categorical_accuracy: 0.9333
# Epoch 114/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3143 - categorical_accuracy: 0.9160 - val_loss: 0.7583 - val_categorical_accuracy: 0.8000
# Epoch 115/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3909 - categorical_accuracy: 0.9076 - val_loss: 0.3490 - val_categorical_accuracy: 0.9333
# Epoch 116/1000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.3358 - categorical_accuracy: 0.9160 - val_loss: 0.3876 - val_categorical_accuracy: 0.8889
# Epoch 117/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3962 - categorical_accuracy: 0.9076 - val_loss: 0.2306 - val_categorical_accuracy: 0.9000
# Epoch 118/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3285 - categorical_accuracy: 0.8964 - val_loss: 0.5760 - val_categorical_accuracy: 0.9000
# Epoch 119/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6308 - categorical_accuracy: 0.8908 - val_loss: 1.0055 - val_categorical_accuracy: 0.7222
# Epoch 120/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 1.0041 - categorical_accuracy: 0.8375 - val_loss: 0.2170 - val_categorical_accuracy: 0.9444
# Epoch 121/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5291 - categorical_accuracy: 0.8655 - val_loss: 0.3555 - val_categorical_accuracy: 0.9111
# Epoch 122/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.4325 - categorical_accuracy: 0.8992 - val_loss: 0.4965 - val_categorical_accuracy: 0.8778
# Epoch 123/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.3668 - categorical_accuracy: 0.9104 - val_loss: 0.3796 - val_categorical_accuracy: 0.9111
# Epoch 124/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3354 - categorical_accuracy: 0.9160 - val_loss: 1.0266 - val_categorical_accuracy: 0.7222
# Epoch 125/1000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4138 - categorical_accuracy: 0.9020 - val_loss: 0.6929 - val_categorical_accuracy: 0.8778
# Epoch 126/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5347 - categorical_accuracy: 0.8824 - val_loss: 0.6264 - val_categorical_accuracy: 0.8333
# Epoch 127/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3627 - categorical_accuracy: 0.9132 - val_loss: 0.2819 - val_categorical_accuracy: 0.9333
# Epoch 128/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2241 - categorical_accuracy: 0.9384 - val_loss: 0.3419 - val_categorical_accuracy: 0.9000
# Epoch 129/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2676 - categorical_accuracy: 0.9244 - val_loss: 0.2181 - val_categorical_accuracy: 0.9333
# Epoch 130/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2597 - categorical_accuracy: 0.9188 - val_loss: 0.1939 - val_categorical_accuracy: 0.9333
# Epoch 131/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2897 - categorical_accuracy: 0.9216 - val_loss: 0.4029 - val_categorical_accuracy: 0.8778
# Epoch 132/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3460 - categorical_accuracy: 0.8824 - val_loss: 0.7163 - val_categorical_accuracy: 0.8667
# Epoch 133/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.5369 - categorical_accuracy: 0.8908 - val_loss: 0.4667 - val_categorical_accuracy: 0.8444
# Epoch 134/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5698 - categorical_accuracy: 0.8908 - val_loss: 0.1925 - val_categorical_accuracy: 0.9444
# Epoch 135/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3297 - categorical_accuracy: 0.9104 - val_loss: 0.2083 - val_categorical_accuracy: 0.9444
# Epoch 136/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2599 - categorical_accuracy: 0.9160 - val_loss: 0.4135 - val_categorical_accuracy: 0.8667
# Epoch 137/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2720 - categorical_accuracy: 0.9160 - val_loss: 0.2355 - val_categorical_accuracy: 0.9333
# Epoch 138/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2035 - categorical_accuracy: 0.9356 - val_loss: 0.3632 - val_categorical_accuracy: 0.8778
# Epoch 139/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2463 - categorical_accuracy: 0.9244 - val_loss: 0.1806 - val_categorical_accuracy: 0.9444
# Epoch 140/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1784 - categorical_accuracy: 0.9440 - val_loss: 0.1784 - val_categorical_accuracy: 0.9333
# Epoch 141/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2758 - categorical_accuracy: 0.9244 - val_loss: 0.3707 - val_categorical_accuracy: 0.8556
# Epoch 142/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2465 - categorical_accuracy: 0.9216 - val_loss: 0.2568 - val_categorical_accuracy: 0.9444
# Epoch 143/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2500 - categorical_accuracy: 0.9272 - val_loss: 0.1833 - val_categorical_accuracy: 0.9444
# Epoch 144/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2242 - categorical_accuracy: 0.9188 - val_loss: 0.1737 - val_categorical_accuracy: 0.9222
# Epoch 145/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1649 - categorical_accuracy: 0.9468 - val_loss: 0.1852 - val_categorical_accuracy: 0.9222
# Epoch 146/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1680 - categorical_accuracy: 0.9384 - val_loss: 0.2271 - val_categorical_accuracy: 0.9444
# Epoch 147/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2551 - categorical_accuracy: 0.9160 - val_loss: 0.1933 - val_categorical_accuracy: 0.9444
# Epoch 148/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1779 - categorical_accuracy: 0.9160 - val_loss: 0.1508 - val_categorical_accuracy: 0.9444
# Epoch 149/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1469 - categorical_accuracy: 0.9412 - val_loss: 0.1467 - val_categorical_accuracy: 0.9444
# Epoch 150/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1596 - categorical_accuracy: 0.9328 - val_loss: 0.2087 - val_categorical_accuracy: 0.9333
# Epoch 151/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2174 - categorical_accuracy: 0.9244 - val_loss: 0.1453 - val_categorical_accuracy: 0.9444
# Epoch 152/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1661 - categorical_accuracy: 0.9384 - val_loss: 0.2371 - val_categorical_accuracy: 0.8889
# Epoch 153/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1969 - categorical_accuracy: 0.9188 - val_loss: 0.1506 - val_categorical_accuracy: 0.9333
# Epoch 154/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2285 - categorical_accuracy: 0.9244 - val_loss: 0.4298 - val_categorical_accuracy: 0.8889
# Epoch 155/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3466 - categorical_accuracy: 0.8992 - val_loss: 0.1718 - val_categorical_accuracy: 0.9556
# Epoch 156/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2045 - categorical_accuracy: 0.9160 - val_loss: 0.4794 - val_categorical_accuracy: 0.8222
# Epoch 157/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2835 - categorical_accuracy: 0.8936 - val_loss: 0.1462 - val_categorical_accuracy: 0.9444
# Epoch 158/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2442 - categorical_accuracy: 0.8908 - val_loss: 1.3900 - val_categorical_accuracy: 0.7444
# Epoch 159/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8033 - categorical_accuracy: 0.8291 - val_loss: 0.8530 - val_categorical_accuracy: 0.7000
# Epoch 160/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 1.1254 - categorical_accuracy: 0.8235 - val_loss: 0.3119 - val_categorical_accuracy: 0.9000
# Epoch 161/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.5395 - categorical_accuracy: 0.8571 - val_loss: 0.5068 - val_categorical_accuracy: 0.8778
# Epoch 162/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5048 - categorical_accuracy: 0.8936 - val_loss: 0.4197 - val_categorical_accuracy: 0.8889
# Epoch 163/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2773 - categorical_accuracy: 0.9244 - val_loss: 0.2361 - val_categorical_accuracy: 0.9333
# Epoch 164/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2930 - categorical_accuracy: 0.9160 - val_loss: 0.2037 - val_categorical_accuracy: 0.9111
# Epoch 165/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3237 - categorical_accuracy: 0.9132 - val_loss: 0.3793 - val_categorical_accuracy: 0.9000
# Epoch 166/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3370 - categorical_accuracy: 0.8992 - val_loss: 0.3482 - val_categorical_accuracy: 0.9333
# Epoch 167/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3115 - categorical_accuracy: 0.9272 - val_loss: 0.3788 - val_categorical_accuracy: 0.8889
# Epoch 168/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2487 - categorical_accuracy: 0.9216 - val_loss: 0.2830 - val_categorical_accuracy: 0.9333
# Epoch 169/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2960 - categorical_accuracy: 0.9188 - val_loss: 0.2005 - val_categorical_accuracy: 0.9111
# Epoch 170/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2203 - categorical_accuracy: 0.9440 - val_loss: 0.1744 - val_categorical_accuracy: 0.9333
# Epoch 171/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1870 - categorical_accuracy: 0.9384 - val_loss: 0.1741 - val_categorical_accuracy: 0.9444
# Epoch 172/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2456 - categorical_accuracy: 0.9384 - val_loss: 0.3131 - val_categorical_accuracy: 0.8889
# Epoch 173/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2457 - categorical_accuracy: 0.9216 - val_loss: 0.1606 - val_categorical_accuracy: 0.9444
# Epoch 174/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1678 - categorical_accuracy: 0.9300 - val_loss: 0.1579 - val_categorical_accuracy: 0.9444
# Epoch 175/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1466 - categorical_accuracy: 0.9440 - val_loss: 0.1801 - val_categorical_accuracy: 0.9111
# Epoch 176/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1934 - categorical_accuracy: 0.9412 - val_loss: 0.1531 - val_categorical_accuracy: 0.9444
# Epoch 177/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2253 - categorical_accuracy: 0.9104 - val_loss: 0.3654 - val_categorical_accuracy: 0.9111
# Epoch 178/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3144 - categorical_accuracy: 0.9076 - val_loss: 0.2578 - val_categorical_accuracy: 0.8778
# Epoch 179/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2182 - categorical_accuracy: 0.9300 - val_loss: 0.1367 - val_categorical_accuracy: 0.9444
# Epoch 180/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3041 - categorical_accuracy: 0.9188 - val_loss: 0.2544 - val_categorical_accuracy: 0.9222
# Epoch 181/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2550 - categorical_accuracy: 0.9104 - val_loss: 0.1330 - val_categorical_accuracy: 0.9444
# Epoch 182/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.3158 - categorical_accuracy: 0.9132 - val_loss: 1.0254 - val_categorical_accuracy: 0.6778
# Epoch 183/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6144 - categorical_accuracy: 0.8207 - val_loss: 0.1864 - val_categorical_accuracy: 0.9222
# Epoch 184/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4446 - categorical_accuracy: 0.8711 - val_loss: 0.4680 - val_categorical_accuracy: 0.8778
# Epoch 185/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3798 - categorical_accuracy: 0.8880 - val_loss: 0.1519 - val_categorical_accuracy: 0.9333
# Epoch 186/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2799 - categorical_accuracy: 0.9160 - val_loss: 0.6058 - val_categorical_accuracy: 0.8111
# Epoch 187/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3567 - categorical_accuracy: 0.9076 - val_loss: 0.3660 - val_categorical_accuracy: 0.9111
# Epoch 188/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3900 - categorical_accuracy: 0.9020 - val_loss: 0.2041 - val_categorical_accuracy: 0.9111
# Epoch 189/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2063 - categorical_accuracy: 0.9468 - val_loss: 0.1751 - val_categorical_accuracy: 0.9444
# Epoch 190/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2150 - categorical_accuracy: 0.9384 - val_loss: 0.1879 - val_categorical_accuracy: 0.9444
# Epoch 191/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2225 - categorical_accuracy: 0.9384 - val_loss: 0.2586 - val_categorical_accuracy: 0.9111
# Epoch 192/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2506 - categorical_accuracy: 0.9244 - val_loss: 0.2700 - val_categorical_accuracy: 0.9333
# Epoch 193/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1981 - categorical_accuracy: 0.9216 - val_loss: 0.6477 - val_categorical_accuracy: 0.7889
# Epoch 194/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.4565 - categorical_accuracy: 0.9048 - val_loss: 0.2648 - val_categorical_accuracy: 0.9333
# Epoch 195/1000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.3797 - categorical_accuracy: 0.8852 - val_loss: 0.3396 - val_categorical_accuracy: 0.9111
# Epoch 196/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4815 - categorical_accuracy: 0.9132 - val_loss: 1.0018 - val_categorical_accuracy: 0.6889
# Epoch 197/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4800 - categorical_accuracy: 0.8599 - val_loss: 0.6776 - val_categorical_accuracy: 0.8444
# Epoch 198/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6148 - categorical_accuracy: 0.8683 - val_loss: 0.1591 - val_categorical_accuracy: 0.9333
# Epoch 199/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3532 - categorical_accuracy: 0.9356 - val_loss: 0.1712 - val_categorical_accuracy: 0.9222
# Epoch 200/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2501 - categorical_accuracy: 0.9188 - val_loss: 0.2884 - val_categorical_accuracy: 0.9333
# Epoch 201/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.4179 - categorical_accuracy: 0.9104 - val_loss: 0.5924 - val_categorical_accuracy: 0.8333
# Epoch 202/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2697 - categorical_accuracy: 0.9244 - val_loss: 0.5376 - val_categorical_accuracy: 0.8889
# Epoch 203/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.4998 - categorical_accuracy: 0.8880 - val_loss: 0.7038 - val_categorical_accuracy: 0.8000
# Epoch 204/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5560 - categorical_accuracy: 0.8739 - val_loss: 0.1895 - val_categorical_accuracy: 0.9444
# Epoch 205/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4574 - categorical_accuracy: 0.8936 - val_loss: 0.3128 - val_categorical_accuracy: 0.9333
# Epoch 206/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.7199 - categorical_accuracy: 0.8936 - val_loss: 1.0188 - val_categorical_accuracy: 0.7222
# Epoch 207/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5498 - categorical_accuracy: 0.8655 - val_loss: 0.2973 - val_categorical_accuracy: 0.9333
# Epoch 208/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3588 - categorical_accuracy: 0.9104 - val_loss: 0.2505 - val_categorical_accuracy: 0.9111
# Epoch 209/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2223 - categorical_accuracy: 0.9300 - val_loss: 0.1934 - val_categorical_accuracy: 0.9333
# Epoch 210/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2284 - categorical_accuracy: 0.9328 - val_loss: 0.1897 - val_categorical_accuracy: 0.9333
# Epoch 211/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2229 - categorical_accuracy: 0.9328 - val_loss: 0.1923 - val_categorical_accuracy: 0.9333
# Epoch 212/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2249 - categorical_accuracy: 0.9412 - val_loss: 0.2275 - val_categorical_accuracy: 0.9444
# Epoch 213/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2098 - categorical_accuracy: 0.9300 - val_loss: 0.1967 - val_categorical_accuracy: 0.9222
# Epoch 214/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1823 - categorical_accuracy: 0.9412 - val_loss: 0.1825 - val_categorical_accuracy: 0.9333
# Epoch 215/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1700 - categorical_accuracy: 0.9468 - val_loss: 0.2004 - val_categorical_accuracy: 0.9444
# Epoch 216/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1754 - categorical_accuracy: 0.9356 - val_loss: 0.2674 - val_categorical_accuracy: 0.9000
# Epoch 217/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1970 - categorical_accuracy: 0.9328 - val_loss: 0.1973 - val_categorical_accuracy: 0.9444
# Epoch 218/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1747 - categorical_accuracy: 0.9356 - val_loss: 0.1772 - val_categorical_accuracy: 0.9444
# Epoch 219/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2310 - categorical_accuracy: 0.9132 - val_loss: 0.5876 - val_categorical_accuracy: 0.7889
# Epoch 220/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3399 - categorical_accuracy: 0.8908 - val_loss: 0.1708 - val_categorical_accuracy: 0.9444
# Epoch 221/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2245 - categorical_accuracy: 0.9356 - val_loss: 0.1710 - val_categorical_accuracy: 0.9556
# Epoch 222/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1879 - categorical_accuracy: 0.9356 - val_loss: 0.3792 - val_categorical_accuracy: 0.8667
# Epoch 223/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2142 - categorical_accuracy: 0.9272 - val_loss: 0.4224 - val_categorical_accuracy: 0.9000
# Epoch 224/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.4686 - categorical_accuracy: 0.8796 - val_loss: 0.1655 - val_categorical_accuracy: 0.9444
# Epoch 225/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.5273 - categorical_accuracy: 0.9020 - val_loss: 0.9212 - val_categorical_accuracy: 0.7111
# Epoch 226/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.4070 - categorical_accuracy: 0.8880 - val_loss: 0.7478 - val_categorical_accuracy: 0.8444
# Epoch 227/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4988 - categorical_accuracy: 0.8880 - val_loss: 0.3204 - val_categorical_accuracy: 0.9000
# Epoch 228/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2631 - categorical_accuracy: 0.9412 - val_loss: 0.1794 - val_categorical_accuracy: 0.9444
# Epoch 229/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2451 - categorical_accuracy: 0.9272 - val_loss: 0.1801 - val_categorical_accuracy: 0.9444
# Epoch 230/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2608 - categorical_accuracy: 0.9300 - val_loss: 0.3662 - val_categorical_accuracy: 0.8889
# Epoch 231/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.2390 - categorical_accuracy: 0.9300 - val_loss: 0.2196 - val_categorical_accuracy: 0.9333
# Epoch 232/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1933 - categorical_accuracy: 0.9412 - val_loss: 0.4787 - val_categorical_accuracy: 0.8556
# Epoch 233/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3863 - categorical_accuracy: 0.9048 - val_loss: 0.1751 - val_categorical_accuracy: 0.9444
# Epoch 234/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2833 - categorical_accuracy: 0.9104 - val_loss: 0.1759 - val_categorical_accuracy: 0.9444
# Epoch 235/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1871 - categorical_accuracy: 0.9440 - val_loss: 0.2914 - val_categorical_accuracy: 0.9111
# Epoch 236/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2446 - categorical_accuracy: 0.9188 - val_loss: 0.1608 - val_categorical_accuracy: 0.9444
# Epoch 237/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1588 - categorical_accuracy: 0.9440 - val_loss: 0.1604 - val_categorical_accuracy: 0.9444
# Epoch 238/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1462 - categorical_accuracy: 0.9412 - val_loss: 0.1535 - val_categorical_accuracy: 0.9444
# Epoch 239/1000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1579 - categorical_accuracy: 0.9356 - val_loss: 0.1650 - val_categorical_accuracy: 0.9444
# Epoch 240/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1469 - categorical_accuracy: 0.9468 - val_loss: 0.1557 - val_categorical_accuracy: 0.9444
# Epoch 241/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1450 - categorical_accuracy: 0.9384 - val_loss: 0.3221 - val_categorical_accuracy: 0.8667
# Epoch 242/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1921 - categorical_accuracy: 0.9188 - val_loss: 0.1986 - val_categorical_accuracy: 0.9444
# Epoch 243/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1873 - categorical_accuracy: 0.9272 - val_loss: 0.1829 - val_categorical_accuracy: 0.9444
# Epoch 244/1000
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1635 - categorical_accuracy: 0.9384 - val_loss: 0.2539 - val_categorical_accuracy: 0.8889
# Epoch 245/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1609 - categorical_accuracy: 0.9328 - val_loss: 0.2207 - val_categorical_accuracy: 0.9333
# Epoch 246/1000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2353 - categorical_accuracy: 0.9104 - val_loss: 0.1478 - val_categorical_accuracy: 0.9222
# Epoch 247/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2585 - categorical_accuracy: 0.9132 - val_loss: 0.5298 - val_categorical_accuracy: 0.8222
# Epoch 248/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2476 - categorical_accuracy: 0.9272 - val_loss: 0.1557 - val_categorical_accuracy: 0.9556
# Epoch 249/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2206 - categorical_accuracy: 0.9188 - val_loss: 0.2140 - val_categorical_accuracy: 0.9444
# Epoch 250/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2331 - categorical_accuracy: 0.9160 - val_loss: 0.4064 - val_categorical_accuracy: 0.8667
# Epoch 251/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2392 - categorical_accuracy: 0.9188 - val_loss: 0.1336 - val_categorical_accuracy: 0.9444
# Epoch 252/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1485 - categorical_accuracy: 0.9440 - val_loss: 0.1573 - val_categorical_accuracy: 0.9556
# Epoch 253/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1562 - categorical_accuracy: 0.9356 - val_loss: 0.5819 - val_categorical_accuracy: 0.8111
# Epoch 254/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.3696 - categorical_accuracy: 0.8936 - val_loss: 0.1323 - val_categorical_accuracy: 0.9444
# Epoch 255/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1318 - categorical_accuracy: 0.9496 - val_loss: 0.1233 - val_categorical_accuracy: 0.9556
# Epoch 256/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1241 - categorical_accuracy: 0.9468 - val_loss: 0.1281 - val_categorical_accuracy: 0.9444
# Epoch 257/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1562 - categorical_accuracy: 0.9412 - val_loss: 0.1205 - val_categorical_accuracy: 0.9444
# Epoch 258/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1660 - categorical_accuracy: 0.9440 - val_loss: 0.2609 - val_categorical_accuracy: 0.8889
# Epoch 259/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2007 - categorical_accuracy: 0.9384 - val_loss: 0.6929 - val_categorical_accuracy: 0.8333
# Epoch 260/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.4491 - categorical_accuracy: 0.8880 - val_loss: 0.1285 - val_categorical_accuracy: 0.9333
# Epoch 261/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3552 - categorical_accuracy: 0.9076 - val_loss: 0.8091 - val_categorical_accuracy: 0.7000
# Epoch 262/1000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4833 - categorical_accuracy: 0.8655 - val_loss: 0.1324 - val_categorical_accuracy: 0.9444
# Epoch 263/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2809 - categorical_accuracy: 0.9188 - val_loss: 0.2829 - val_categorical_accuracy: 0.9222
# Epoch 264/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2667 - categorical_accuracy: 0.9272 - val_loss: 0.2555 - val_categorical_accuracy: 0.9222
# Epoch 265/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2074 - categorical_accuracy: 0.9216 - val_loss: 0.1233 - val_categorical_accuracy: 0.9333
# Epoch 266/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1753 - categorical_accuracy: 0.9468 - val_loss: 0.2394 - val_categorical_accuracy: 0.9333
# Epoch 267/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2874 - categorical_accuracy: 0.9216 - val_loss: 0.1331 - val_categorical_accuracy: 0.9444
# Epoch 268/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1538 - categorical_accuracy: 0.9356 - val_loss: 0.1952 - val_categorical_accuracy: 0.9111
# Epoch 269/1000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1544 - categorical_accuracy: 0.9440 - val_loss: 0.3199 - val_categorical_accuracy: 0.9000
# Epoch 270/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3420 - categorical_accuracy: 0.8796 - val_loss: 0.1547 - val_categorical_accuracy: 0.9556
# Epoch 271/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2499 - categorical_accuracy: 0.9300 - val_loss: 0.2910 - val_categorical_accuracy: 0.9000
# Epoch 272/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1811 - categorical_accuracy: 0.9468 - val_loss: 0.3078 - val_categorical_accuracy: 0.9000
# Epoch 273/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2709 - categorical_accuracy: 0.9076 - val_loss: 0.1242 - val_categorical_accuracy: 0.9556
# Epoch 274/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1706 - categorical_accuracy: 0.9440 - val_loss: 0.1826 - val_categorical_accuracy: 0.9111
# Epoch 275/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1543 - categorical_accuracy: 0.9440 - val_loss: 0.1190 - val_categorical_accuracy: 0.9444
# Epoch 276/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1252 - categorical_accuracy: 0.9412 - val_loss: 0.1312 - val_categorical_accuracy: 0.9444
# Epoch 277/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1339 - categorical_accuracy: 0.9384 - val_loss: 0.1583 - val_categorical_accuracy: 0.9222
# Epoch 278/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1330 - categorical_accuracy: 0.9524 - val_loss: 0.1345 - val_categorical_accuracy: 0.9556
# Epoch 279/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1633 - categorical_accuracy: 0.9384 - val_loss: 0.2466 - val_categorical_accuracy: 0.9333
# Epoch 280/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2127 - categorical_accuracy: 0.9300 - val_loss: 0.1517 - val_categorical_accuracy: 0.9222
# Epoch 281/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1559 - categorical_accuracy: 0.9440 - val_loss: 0.1349 - val_categorical_accuracy: 0.9222
# Epoch 282/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1518 - categorical_accuracy: 0.9468 - val_loss: 0.3655 - val_categorical_accuracy: 0.8889
# Epoch 283/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3499 - categorical_accuracy: 0.9132 - val_loss: 0.2757 - val_categorical_accuracy: 0.9000
# Epoch 284/1000
# ...
# Epoch 906/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.3012 - categorical_accuracy: 0.9048 - val_loss: 0.2288 - val_categorical_accuracy: 0.9444
# Epoch 907/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.2698 - categorical_accuracy: 0.9272 - val_loss: 0.0724 - val_categorical_accuracy: 0.9667
# Epoch 908/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2264 - categorical_accuracy: 0.9468 - val_loss: 0.0698 - val_categorical_accuracy: 0.9778
# Epoch 909/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1945 - categorical_accuracy: 0.9440 - val_loss: 0.0635 - val_categorical_accuracy: 0.9778
# Epoch 910/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1570 - categorical_accuracy: 0.9412 - val_loss: 0.1421 - val_categorical_accuracy: 0.9444
# Epoch 911/1000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1498 - categorical_accuracy: 0.9524 - val_loss: 0.0858 - val_categorical_accuracy: 0.9667
# Epoch 912/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1316 - categorical_accuracy: 0.9440 - val_loss: 0.1380 - val_categorical_accuracy: 0.9333
# Epoch 913/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1143 - categorical_accuracy: 0.9552 - val_loss: 0.1500 - val_categorical_accuracy: 0.9444
# Epoch 914/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1174 - categorical_accuracy: 0.9552 - val_loss: 0.1548 - val_categorical_accuracy: 0.9222
# Epoch 915/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1543 - categorical_accuracy: 0.9468 - val_loss: 0.2102 - val_categorical_accuracy: 0.9333
# Epoch 916/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1606 - categorical_accuracy: 0.9468 - val_loss: 0.2143 - val_categorical_accuracy: 0.9111
# Epoch 917/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1987 - categorical_accuracy: 0.9412 - val_loss: 0.1282 - val_categorical_accuracy: 0.9444
# Epoch 918/1000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1491 - categorical_accuracy: 0.9468 - val_loss: 0.0530 - val_categorical_accuracy: 0.9778
# Epoch 919/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1150 - categorical_accuracy: 0.9664 - val_loss: 0.0444 - val_categorical_accuracy: 0.9778
# Epoch 920/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1470 - categorical_accuracy: 0.9496 - val_loss: 0.1079 - val_categorical_accuracy: 0.9667
# Epoch 921/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1794 - categorical_accuracy: 0.9496 - val_loss: 0.2618 - val_categorical_accuracy: 0.9111
# Epoch 922/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1866 - categorical_accuracy: 0.9440 - val_loss: 0.0569 - val_categorical_accuracy: 0.9778
# Epoch 923/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0798 - categorical_accuracy: 0.9636 - val_loss: 0.0521 - val_categorical_accuracy: 0.9778
# Epoch 924/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0915 - categorical_accuracy: 0.9692 - val_loss: 0.0511 - val_categorical_accuracy: 0.9778
# Epoch 925/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1084 - categorical_accuracy: 0.9608 - val_loss: 0.0512 - val_categorical_accuracy: 0.9778
# Epoch 926/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1026 - categorical_accuracy: 0.9664 - val_loss: 0.0430 - val_categorical_accuracy: 0.9778
# Epoch 927/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0702 - categorical_accuracy: 0.9664 - val_loss: 0.0413 - val_categorical_accuracy: 0.9778
# Epoch 928/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0793 - categorical_accuracy: 0.9580 - val_loss: 0.0416 - val_categorical_accuracy: 0.9778
# Epoch 929/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0745 - categorical_accuracy: 0.9580 - val_loss: 0.0625 - val_categorical_accuracy: 0.9778
# Epoch 930/1000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0702 - categorical_accuracy: 0.9720 - val_loss: 0.0688 - val_categorical_accuracy: 0.9778
# Epoch 931/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0825 - categorical_accuracy: 0.9664 - val_loss: 0.1269 - val_categorical_accuracy: 0.9556
# Epoch 932/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1837 - categorical_accuracy: 0.9356 - val_loss: 0.0401 - val_categorical_accuracy: 0.9778
# Epoch 933/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1521 - categorical_accuracy: 0.9356 - val_loss: 0.1980 - val_categorical_accuracy: 0.9222
# Epoch 934/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1840 - categorical_accuracy: 0.9356 - val_loss: 0.0565 - val_categorical_accuracy: 0.9778
# Epoch 935/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0851 - categorical_accuracy: 0.9664 - val_loss: 0.0401 - val_categorical_accuracy: 0.9889
# Epoch 936/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0860 - categorical_accuracy: 0.9636 - val_loss: 0.0700 - val_categorical_accuracy: 0.9778
# Epoch 937/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0946 - categorical_accuracy: 0.9608 - val_loss: 0.1146 - val_categorical_accuracy: 0.9556
# Epoch 938/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1053 - categorical_accuracy: 0.9692 - val_loss: 0.1281 - val_categorical_accuracy: 0.9556
# Epoch 939/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0993 - categorical_accuracy: 0.9664 - val_loss: 0.1345 - val_categorical_accuracy: 0.9444
# Epoch 940/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1722 - categorical_accuracy: 0.9496 - val_loss: 0.1692 - val_categorical_accuracy: 0.9333
# Epoch 941/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1205 - categorical_accuracy: 0.9608 - val_loss: 0.0817 - val_categorical_accuracy: 0.9667
# Epoch 942/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1490 - categorical_accuracy: 0.9496 - val_loss: 0.0436 - val_categorical_accuracy: 0.9889
# Epoch 943/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1760 - categorical_accuracy: 0.9328 - val_loss: 0.0684 - val_categorical_accuracy: 0.9778
# Epoch 944/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1974 - categorical_accuracy: 0.9412 - val_loss: 0.2243 - val_categorical_accuracy: 0.9111
# Epoch 945/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1843 - categorical_accuracy: 0.9384 - val_loss: 0.2639 - val_categorical_accuracy: 0.9111
# Epoch 946/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1722 - categorical_accuracy: 0.9412 - val_loss: 0.0508 - val_categorical_accuracy: 0.9778
# Epoch 947/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1374 - categorical_accuracy: 0.9440 - val_loss: 0.0424 - val_categorical_accuracy: 0.9778
# Epoch 948/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2171 - categorical_accuracy: 0.9328 - val_loss: 0.1856 - val_categorical_accuracy: 0.9111
# Epoch 949/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.3051 - categorical_accuracy: 0.9160 - val_loss: 0.4721 - val_categorical_accuracy: 0.8444
# Epoch 950/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2874 - categorical_accuracy: 0.9272 - val_loss: 0.1089 - val_categorical_accuracy: 0.9556
# Epoch 951/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1532 - categorical_accuracy: 0.9412 - val_loss: 0.0440 - val_categorical_accuracy: 0.9889
# Epoch 952/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1265 - categorical_accuracy: 0.9468 - val_loss: 0.0529 - val_categorical_accuracy: 0.9778
# Epoch 953/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0991 - categorical_accuracy: 0.9580 - val_loss: 0.0520 - val_categorical_accuracy: 0.9778
# Epoch 954/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0976 - categorical_accuracy: 0.9636 - val_loss: 0.0587 - val_categorical_accuracy: 0.9778
# Epoch 955/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0895 - categorical_accuracy: 0.9580 - val_loss: 0.0528 - val_categorical_accuracy: 0.9778
# Epoch 956/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0721 - categorical_accuracy: 0.9636 - val_loss: 0.0569 - val_categorical_accuracy: 0.9778
# Epoch 957/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0799 - categorical_accuracy: 0.9552 - val_loss: 0.0499 - val_categorical_accuracy: 0.9778
# Epoch 958/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0736 - categorical_accuracy: 0.9692 - val_loss: 0.0456 - val_categorical_accuracy: 0.9778
# Epoch 959/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0821 - categorical_accuracy: 0.9608 - val_loss: 0.0615 - val_categorical_accuracy: 0.9778
# Epoch 960/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0899 - categorical_accuracy: 0.9692 - val_loss: 0.0575 - val_categorical_accuracy: 0.9889
# Epoch 961/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0718 - categorical_accuracy: 0.9664 - val_loss: 0.0560 - val_categorical_accuracy: 0.9778
# Epoch 962/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0857 - categorical_accuracy: 0.9636 - val_loss: 0.0385 - val_categorical_accuracy: 0.9778
# Epoch 963/1000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0744 - categorical_accuracy: 0.9608 - val_loss: 0.0393 - val_categorical_accuracy: 0.9778
# Epoch 964/1000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0786 - categorical_accuracy: 0.9636 - val_loss: 0.0419 - val_categorical_accuracy: 0.9778
# Epoch 965/1000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0755 - categorical_accuracy: 0.9692 - val_loss: 0.0378 - val_categorical_accuracy: 0.9778
# Epoch 966/1000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0723 - categorical_accuracy: 0.9580 - val_loss: 0.0424 - val_categorical_accuracy: 0.9778
# Epoch 967/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0836 - categorical_accuracy: 0.9608 - val_loss: 0.0412 - val_categorical_accuracy: 0.9778
# Epoch 968/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0877 - categorical_accuracy: 0.9692 - val_loss: 0.0411 - val_categorical_accuracy: 0.9778
# Epoch 969/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0788 - categorical_accuracy: 0.9608 - val_loss: 0.0732 - val_categorical_accuracy: 0.9667
# Epoch 970/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0939 - categorical_accuracy: 0.9636 - val_loss: 0.1075 - val_categorical_accuracy: 0.9556
# Epoch 971/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1168 - categorical_accuracy: 0.9580 - val_loss: 0.0367 - val_categorical_accuracy: 0.9778
# Epoch 972/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0948 - categorical_accuracy: 0.9580 - val_loss: 0.0395 - val_categorical_accuracy: 0.9778
# Epoch 973/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0869 - categorical_accuracy: 0.9692 - val_loss: 0.1225 - val_categorical_accuracy: 0.9556
# Epoch 974/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1099 - categorical_accuracy: 0.9580 - val_loss: 0.0422 - val_categorical_accuracy: 0.9778
# Epoch 975/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0885 - categorical_accuracy: 0.9692 - val_loss: 0.0350 - val_categorical_accuracy: 0.9778
# Epoch 976/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0849 - categorical_accuracy: 0.9636 - val_loss: 0.0790 - val_categorical_accuracy: 0.9778
# Epoch 977/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1331 - categorical_accuracy: 0.9524 - val_loss: 0.3646 - val_categorical_accuracy: 0.8444
# Epoch 978/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.3429 - categorical_accuracy: 0.9104 - val_loss: 0.9397 - val_categorical_accuracy: 0.7111
# Epoch 979/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5090 - categorical_accuracy: 0.8599 - val_loss: 0.0401 - val_categorical_accuracy: 0.9778
# Epoch 980/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1606 - categorical_accuracy: 0.9356 - val_loss: 0.0348 - val_categorical_accuracy: 0.9889
# Epoch 981/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1674 - categorical_accuracy: 0.9552 - val_loss: 0.1069 - val_categorical_accuracy: 0.9444
# Epoch 982/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1318 - categorical_accuracy: 0.9496 - val_loss: 0.0626 - val_categorical_accuracy: 0.9667
# Epoch 983/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1426 - categorical_accuracy: 0.9552 - val_loss: 0.1169 - val_categorical_accuracy: 0.9444
# Epoch 984/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1206 - categorical_accuracy: 0.9552 - val_loss: 0.1042 - val_categorical_accuracy: 0.9556
# Epoch 985/1000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1053 - categorical_accuracy: 0.9580 - val_loss: 0.1251 - val_categorical_accuracy: 0.9444
# Epoch 986/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1044 - categorical_accuracy: 0.9524 - val_loss: 0.0825 - val_categorical_accuracy: 0.9778
# Epoch 987/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0816 - categorical_accuracy: 0.9748 - val_loss: 0.0663 - val_categorical_accuracy: 0.9667
# Epoch 988/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0859 - categorical_accuracy: 0.9692 - val_loss: 0.0523 - val_categorical_accuracy: 0.9778
# Epoch 989/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0777 - categorical_accuracy: 0.9608 - val_loss: 0.0444 - val_categorical_accuracy: 0.9778
# Epoch 990/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0733 - categorical_accuracy: 0.9636 - val_loss: 0.0396 - val_categorical_accuracy: 0.9778
# Epoch 991/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0710 - categorical_accuracy: 0.9608 - val_loss: 0.0528 - val_categorical_accuracy: 0.9778
# Epoch 992/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0976 - categorical_accuracy: 0.9580 - val_loss: 0.0442 - val_categorical_accuracy: 0.9778
# Epoch 993/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0721 - categorical_accuracy: 0.9664 - val_loss: 0.0446 - val_categorical_accuracy: 0.9667
# Epoch 994/1000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0715 - categorical_accuracy: 0.9636 - val_loss: 0.0417 - val_categorical_accuracy: 0.9778
# Epoch 995/1000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0757 - categorical_accuracy: 0.9692 - val_loss: 0.0428 - val_categorical_accuracy: 0.9778
# Epoch 996/1000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0705 - categorical_accuracy: 0.9692 - val_loss: 0.0752 - val_categorical_accuracy: 0.9667
# Epoch 997/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1068 - categorical_accuracy: 0.9608 - val_loss: 0.0385 - val_categorical_accuracy: 0.9778
# Epoch 998/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0657 - categorical_accuracy: 0.9636 - val_loss: 0.0465 - val_categorical_accuracy: 0.9889
# Epoch 999/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0708 - categorical_accuracy: 0.9720 - val_loss: 0.0404 - val_categorical_accuracy: 0.9778
# Epoch 1000/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0818 - categorical_accuracy: 0.9720 - val_loss: 0.0493 - val_categorical_accuracy: 0.9778

# %% [markdown]
# You will need to convert the output of your model to be 'M' or 'B' for each test sample. This depends on if you used boolean or one-hot encoding for the targets (or probabilities). You may need to adjust the examples below for your model.

# %%
# Uncomment if you used one-hot encoding:
final_predictions = ['M' if prediction == 1 else 'B' for prediction in np.argmax(predictions, axis=1)]

# Uncomment if you boolean encoding:
#final_predictions = ['M' if prediction == 1 else 'B' for prediction in predictions]

# %% [markdown]
# Now to save the output to a CSV file:

# %%
pd.DataFrame(data={'Diagnosis': final_predictions}).to_csv('predictions.csv', index_label='Id')

# %% [markdown]
# To resubmit, run your model cell (after changes), the CSV file cell and the cell below.

# %%
# !python3 /usr/local/bin/kaggle competitions submit -m $URN -c uos-com2028-21-22-lab3 -f predictions.csv
# Out:
# 100% 581/581 [00:01<00:00, 534B/s]
# Successfully submitted to COM2028 21/22 Lab 3

# %% [markdown]
# Your score should soon [show up on Kaggle](https://www.kaggle.com/c/uos-com2028-21-22-lab3/submissions)...
